# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
lower_cols = [col.lower() for col in df.columns]
lower_cols#Your code here
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits                                                               ']

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df = df.set_index('LINENAME')
df.head()#Your code here
# Out:
#            C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# LINENAME
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              DESC  ENTRIES  \
# LINENAME
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           EXITS
# LINENAME
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df = df.reset_index()
df.head()# Your code here
# Out:
#   LINENAME   C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df['Num_Lines'] = df.LINENAME.map(lambda x: len(x))
df.head()# Your code here
# Out:
#   LINENAME   C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.capitalize()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['Linename', 'C/a', 'Unit', 'Scp', 'Station', 'Division', 'Date', 'Time',
#        'Desc', 'Entries',
#        'Exits                                                               ',
#        'Num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df.Date = pd.to_datetime(df.Date)#Your code here
print(df.Date.dtype)
df.head()
# Out:
# datetime64[ns]
#   Linename   C/a  Unit       Scp Station Division       Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %%
df['Dayofweek']=df.Date.dt.day_name()
df.head()
# Out:
#   Linename   C/a  Unit       Scp Station Division       Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_lines Dayofweek
# 0          7  Saturday
# 1          7  Saturday
# 2          7  Saturday
# 3          7  Saturday
# 4          7  Saturday

# %%
grouped = df.groupby('Dayofweek').sum()
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
grouped = grouped.reset_index()
grouped.head()
# Out:
#   Dayofweek        Entries  \
# 0    Friday  1110224700078
# 1    Monday  1114237052454
# 2  Saturday  1115661545514
# 3    Sunday  1192306179082
# 4  Thursday  1122723988662
#
#    Exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    Num_lines
# 0      75573
# 1      76110
# 2      74725
# 3      75306
# 4      76607

# %%
grouped['Weekend'] = grouped.Dayofweek.map({'Monday':False,'Tuesday':False,'Wednesday':False,'Thursday':False,'Friday':False,'Saturday':True,'Sunday':True})
grouped.head()
# Out:
#   Dayofweek        Entries  \
# 0    Friday  1110224700078
# 1    Monday  1114237052454
# 2  Saturday  1115661545514
# 3    Sunday  1192306179082
# 4  Thursday  1122723988662
#
#    Exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    Num_lines  Weekend
# 0      75573    False
# 1      76110    False
# 2      74725     True
# 3      75306     True
# 4      76607    False

# %%
wkend = grouped.groupby('Weekend').mean()
wkend.plot(kind='barh')

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
df.head(2)# Your code here
# Out:
#   Linename   C/a  Unit       Scp Station Division       Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
#
#    Num_lines Dayofweek
# 0          7  Saturday
# 1          7  Saturday

# %%
df= df.drop(['Scp','Division'], axis=1)
df.head()
# Out:
#   Linename   C/a  Unit Station       Date      Time     Desc  Entries  \
# 0  NQR456W  A002  R051   59 ST 2018-08-25  00:00:00  REGULAR  6736067
# 1  NQR456W  A002  R051   59 ST 2018-08-25  04:00:00  REGULAR  6736087
# 2  NQR456W  A002  R051   59 ST 2018-08-25  08:00:00  REGULAR  6736105
# 3  NQR456W  A002  R051   59 ST 2018-08-25  12:00:00  REGULAR  6736180
# 4  NQR456W  A002  R051   59 ST 2018-08-25  16:00:00  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_lines Dayofweek
# 0          7  Saturday
# 1          7  Saturday
# 2          7  Saturday
# 3          7  Saturday
# 4          7  Saturday
